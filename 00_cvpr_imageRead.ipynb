# %% [markdown]
# <a href="https://colab.research.google.com/github/delowerhossentuhin/Computer-Vision-and-Pattern-Recognition-/blob/main/00_cvpr_imageRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
image1=plt.imread("Joker.jpg")

# %%
plt.imshow(image1)
plt.axis("off")
plt.show()

# %%
print(type(image1))
print(image1.shape)
# Out:
# <class 'numpy.ndarray'>
# (900, 720, 3)

# %%
print(image1)
# Out:
# [[[ 75  75  75]
#   [ 78  78  78]
#   [ 78  78  78]
#   ...
#   [ 25  25  25]
#   [ 25  25  25]
#   [ 25  25  25]]
#
#  [[ 78  78  78]
#   [ 81  81  81]
#   [ 81  81  81]
#   ...
#   [ 28  28  28]
#   [ 29  29  29]
#   [ 29  29  29]]
#
#  [[ 81  81  81]
#   [ 83  83  83]
#   [ 83  83  83]
#   ...
#   [ 29  29  29]
#   [ 30  30  30]
#   [ 30  30  30]]
#
#  ...
#
#  [[167 167 167]
#   [174 174 174]
#   [175 175 175]
#   ...
#   [141 141 141]
#   [141 141 141]
#   [142 142 142]]
#
#  [[165 165 165]
#   [175 175 175]
#   [179 179 179]
#   ...
#   [145 145 145]
#   [149 149 149]
#   [150 150 150]]
#
#  [[162 162 162]
#   [175 175 175]
#   [183 183 183]
#   ...
#   [146 146 146]
#   [151 151 151]
#   [153 153 153]]]
